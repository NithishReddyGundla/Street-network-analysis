# %%
# !pip install osmnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import networkx as nx
import osmnx as ox
from IPython.display import IFrame

# %matplotlib inline
ox.__version__
# Out:
# '1.3.0'

# %%
G = ox.graph_from_address('San Antonio Downtown, Texas, USA', dist=2000, simplify=True, network_type='drive')

# %%
# plot the street network with folium
m1 = ox.plot_graph_folium(G, popup_attribute="name", weight=2, color="#8b0000")

# %%
# save as html file then display map as an iframe
filepath = "/content/drive/MyDrive/Colab Notebooks/Final Graduate Project/Road network analys - OSMnx/data/route.html"
m1.save(filepath)
IFrame(filepath, width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="/content/drive/MyDrive/Colab Notebooks/Final Graduate Project/Road network analys - OSMnx/data/route.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **Plot a route as an interactive web map**

# %%
# use networkx to calculate the shortest path between two nodes
origin_node = list(G.nodes())[0]
destination_node = list(G.nodes())[-1]
route = nx.shortest_path(G, origin_node, destination_node)

# %%
# plot the route with folium
# like above, you can pass keyword args along to folium PolyLine to style the lines
m2 = ox.plot_route_folium(G, route, weight=10)

# %%
# save as html file then display map as an iframe
filepath = "/content/drive/MyDrive/Colab Notebooks/Final Graduate Project/Road network analys - OSMnx/data/route.html"
m2.save(filepath)
IFrame(filepath, width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="/content/drive/MyDrive/Colab Notebooks/Final Graduate Project/Road network analys - OSMnx/data/route.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **Or plot a route on top of the complete street network map**

# %%
# plot the route with folium on top of the previously created graph_map
m3 = ox.plot_route_folium(G, route, route_map=m1, popup_attribute="length", weight=7)

# %%
# save as html file then display map as an iframe
filepath = "/content/drive/MyDrive/Colab Notebooks/Final Graduate Project/Road network analys - OSMnx/data/route_graph.html"
m3.save(filepath)
IFrame(filepath, width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height="500"
#             src="/content/drive/MyDrive/Colab Notebooks/Final Graduate Project/Road network analys - OSMnx/data/route_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
